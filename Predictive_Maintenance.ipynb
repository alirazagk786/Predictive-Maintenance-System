# %% [markdown]
# #**Predictive Maintenance** : **Data Analysis & Time-Series Forecasting**

# %%
#Importing Libraries and defining functions for plotting the data using **matplotlib**
import os
import sys
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime

matplotlib.style.use("Solarize_Light2")

# %matplotlib inline

# %%
#Reading_Data
Data_Dir = "/content/drive/MyDrive/Maintance_prediction"

telemetry_df = pd.read_csv("/content/drive/MyDrive/Maintance_prediction/dataset/PdM_telemetry.csv")
errors_df = pd.read_csv("/content/drive/MyDrive/Maintance_prediction/dataset/PdM_errors.csv")
maint_df = pd.read_csv("/content/drive/MyDrive/Maintance_prediction/dataset/PdM_maint.csv")
failure_df = pd.read_csv("/content/drive/MyDrive/Maintance_prediction/dataset/PdM_failures.csv")
machines_df = pd.read_csv("/content/drive/MyDrive/Maintance_prediction/dataset/PdM_machines.csv")

#Date and Time Formatting, Sorting based on Date for better readability
tables = [telemetry_df,errors_df,maint_df,failure_df]
for df in tables:
  df["datetime"] = pd.to_datetime(df["datetime"], format = "%Y-%m-%d %H:%M:%S")
  df.sort_values(["datetime","machineID"],inplace=True, ignore_index = True)

# %%
failure_df.head()
# Out:
#              datetime  machineID failure
# 0 2015-01-02 03:00:00         16   comp1
# 1 2015-01-02 03:00:00         16   comp3
# 2 2015-01-02 03:00:00         17   comp4
# 3 2015-01-02 03:00:00         22   comp1
# 4 2015-01-02 03:00:00         35   comp1

# %% [markdown]
# **Telemetry Data**

# %%
#First few rows of Telemetry data for Machine 1
telemetry_df[telemetry_df.machineID==1].head()
# Out:
#                datetime  machineID        volt      rotate    pressure  \
# 0   2015-01-01 06:00:00          1  176.217853  418.504078  113.077935
# 100 2015-01-01 07:00:00          1  162.879223  402.747490   95.460525
# 200 2015-01-01 08:00:00          1  170.989902  527.349825   75.237905
# 300 2015-01-01 09:00:00          1  162.462833  346.149335  109.248561
# 400 2015-01-01 10:00:00          1  157.610021  435.376873  111.886648
#
#      vibration
# 0    45.087686
# 100  43.413973
# 200  34.178847
# 300  41.122144
# 400  25.990511

# %%
#Machine Count
telemetry_df.machineID.nunique()
# Out:
# 100

# %%
#Duration of the data
telemetry_df.datetime.describe(datetime_is_numeric=True)
# Out:
# count                 876100
# mean     2015-07-02 18:00:00
# min      2015-01-01 06:00:00
# 25%      2015-04-02 12:00:00
# 50%      2015-07-02 18:00:00
# 75%      2015-10-02 00:00:00
# max      2016-01-01 06:00:00
# Name: datetime, dtype: object

# %%
#Duplictes Values


def check_duplicate(data_frame, columns_to_check):
    # Check if the input columns are valid
    for col in columns_to_check:
        if col not in data_frame.columns:
            raise ValueError(f"Column '{col}' not found in the DataFrame.")

    # Find duplicate rows based on the specified columns
    duplicate_rows = data_frame[data_frame.duplicated(subset=columns_to_check, keep=False)]

    return duplicate_rows

columns_to_check = ['datetime', 'machineID']
duplicate_rows = check_duplicate(telemetry_df, columns_to_check)
print("Duplicate Rows:")
print(duplicate_rows)
#check_duplicate(telemetry_df,['datetime', 'machineID'])
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [datetime, machineID, volt, rotate, pressure, vibration]
# Index: []

# %%
#Check Null Values

def check_null(data_frame):
    # Check for missing values in the DataFrame
    null_values = data_frame.isnull().sum()
    return null_values

null_values = check_null(telemetry_df)
print("Missing Values:")
print(null_values)
# Out:
# Missing Values:
# datetime     0
# machineID    0
# volt         0
# rotate       0
# pressure     0
# vibration    0
# dtype: int64

# %%
#Let's assume machineID as 10
print(f"Shape of the Telemetry Record: {telemetry_df.shape}")
df_sin = telemetry_df.loc[telemetry_df['machineID']==10].reset_index(drop=True)
df_sin.head(n=5)
# Out:
# Shape of the Telemetry Record: (876100, 6)
#              datetime  machineID        volt      rotate    pressure  \
# 0 2015-01-01 06:00:00         10  158.421261  500.830885  119.750673
# 1 2015-01-01 07:00:00         10  174.631951  356.928821   88.860999
# 2 2015-01-01 08:00:00         10  158.777566  467.162159   84.382394
# 3 2015-01-01 09:00:00         10  178.128852  438.376292  105.870821
# 4 2015-01-01 10:00:00         10  176.497316  364.918330   98.148214
#
#    vibration
# 0  45.571344
# 1  35.245965
# 2  37.975278
# 3  40.836263
# 4  35.511013

# %%
#Failure record of Machine 10
sel_fail = failure_df.loc[failure_df['machineID']==10]
pd.DataFrame(sel_fail)
# Out:
#                datetime  machineID failure
# 55  2015-01-19 06:00:00         10   comp2
# 219 2015-04-04 06:00:00         10   comp2
# 308 2015-05-19 06:00:00         10   comp2
# 338 2015-06-03 06:00:00         10   comp1
# 367 2015-06-18 06:00:00         10   comp2

# %%
#Error Record of Machine 10
sel_err = errors_df.loc[errors_df['machineID']==10]
pd.DataFrame(sel_err).head()
# Out:
#                datetime  machineID errorID
# 10  2015-01-01 20:00:00         10  error1
# 67  2015-01-06 04:00:00         10  error3
# 193 2015-01-18 06:00:00         10  error2
# 194 2015-01-18 06:00:00         10  error3
# 247 2015-01-22 05:00:00         10  error1

# %% [markdown]
# As per the Kaggle Dataset, error refers to non-breaking events while failure referes to event that cause the machine to fail.
#
# So, using chronological plot we will define how error and failure relate with each other.

# %%
fig, ax = plt.subplots()

#Using two values in the y-axis to make it simpler and differentiate between Error and Failure
y_category = list()

for iter in range(0, len(sel_fail)):
  y_category.append("Failure")

for iter in range(0, len(sel_err)):
  y_category.append("Error")

#Timestamp from error and selected failure
timestamp_df = pd.concat([sel_fail['datetime'],sel_err['datetime']], ignore_index=True, axis = 0)
plot_df = pd.DataFrame({'timestamp':timestamp_df,"category":y_category})
plot_df.loc[:, 'timestamp'] = pd.to_datetime(plot_df.loc[:, 'timestamp'])
plot_df.sort_values(by=['timestamp'],inplace = True, ignore_index=True)

# Plotting timestamp as per x-axis
ax.scatter('timestamp', 'category', data = plot_df)
year_fmt = mdates.DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(year_fmt)
ax.tick_params(axis='x',rotation=45)
ax.grid()
# Out:
# <ipython-input-15-dfe0aa14105e>:15: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   plot_df.loc[:, 'timestamp'] = pd.to_datetime(plot_df.loc[:, 'timestamp'])

# %% [markdown]
# From the above plot, we can see that failure are often times preceded by error in the machines. However, not all error results in immediate failure. Some times may passes before the failure in machine occurs.
#
# So, we gotta be focusing on failure data and check which feature is effected by Machine Failure.

# %%
#Feature Check
#Selecting Time Window from the failure record, then plotting each feature and checking there event of failures

df_sin.loc[:, 'datetime'] = pd.to_datetime(df_sin.loc[:, 'datetime']) #Changing Datatype of the timestamp column from object to datetime
st = df_sin.loc[df_sin['datetime']=="2015-02-19"].index.values[0] #Select the date to check from failure record

#Filtering the telemetry data by the date and allow 7 days before and after
#The error will occure to check any abnormalities
select = df_sin.loc[st-7*24:st + 7*24, :]

#Plot Volt and Rotation Feature
fig, ax = plt.subplots(nrows=2, sharex=True)
ax[0].plot('datetime','volt', data=select)
ax[0].set_ylabel('Volt')

ax[1].plot('datetime','rotate',data=select)
ax[1].tick_params(axis='x',rotation = 45)
ax[1].set_xlabel("Timestamp")
ax[1].set_ylabel("Rotation")
# Out:
# <ipython-input-16-aa754abdb8f6>:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_sin.loc[:, 'datetime'] = pd.to_datetime(df_sin.loc[:, 'datetime']) #Changing Datatype of the timestamp column from object to datetime
# Text(0, 0.5, 'Rotation')

# %% [markdown]
# As per the observation by above plots, there is no noticeable anamolies are shown around the period of 2015-02-19.
#
# Now we will check both Pressure and Vibration features by Plotting them.

# %%
fig, ax = plt.subplots(nrows=2, sharex=True)
ax[0].plot('datetime','pressure',data=select)
ax[0].set_ylabel('Pressure')

ax[1].plot('datetime','vibration',data=select)
ax[1].tick_params(axis='x',rotation = 45)
ax[1].set_xlabel("Timestamp")
ax[1].set_ylabel("Vibrations")
# Out:
# Text(0, 0.5, 'Vibrations')

# %%
#Plotting Distribution of Voltage, Rotate, Pressure, and Vibrations

import matplotlib.pyplot as plt
import seaborn as sns

def plot_hist(data_frame, feature_name, log=False, bins=10):
    plt.figure(figsize=(10, 6))
    sns.histplot(data_frame[feature_name], bins=bins, kde=True)

    if log:
        plt.yscale('log')

    plt.title(f'Distribution of {feature_name}')
    plt.xlabel(feature_name)
    plt.ylabel('Frequency')
    plt.show()

for name in ['volt','rotate','pressure','vibration']:
  plot_hist(telemetry_df, feature_name=name, log=False, bins=1000)

# %% [markdown]
# #Checking Autocorrelation and Partial Correlation

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf      #Importing Plotting Function


#Autocorrelation Plot
plot_acf(df_sin['pressure'],lags=40)
plt.show()

# %% [markdown]
# As per the above plot, we can say data is positively correlated up to lags 40.
#
# Where the autocorrelation value itself is quite low, indicating that data does not have a strong autocorrelation properties.

# %%
#Partial Correlation Plot
plot_pacf(df_sin['pressure'],lags=40)
plt.show()

# %% [markdown]
# As per the above plot, we can say the correlation between two different points in time is also quite week, decaying to zero starting in the 15th Lags.
#
#
#
# ---

# %% [markdown]
# # Model Selection
#
# **Preparing Data Input and Output**
# We are using LSTM algorithm. For experimenting, we will be using training data of 1 month containing 2015-03-20 period where failure happened to predict another failure which occure at 2015-05-21 according to failure record.
#
# The feature we are going to use is Pressure reading and Timestamp.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

#Selecting the date to check from failure records
st_train = df_sin.loc[df_sin['datetime']=="2015-03-20"].index.values[0]

#Filtering data to include approximately one month window
start_period = st_train-14*24
end_period = st_train+14*24

def create_feature(start,end):  #Creating Feature from selected machine
  pressure = df_sin.loc[start: end, 'pressure']
  timestamp = pd.to_datetime(df_sin.loc[start: end, 'datetime'])
  timestamp_hour = timestamp.map(lambda x: x.hour)
  timestamp_dow = timestamp.map(lambda x: x.dayofweek)

  #Applying one-hot encode for timestamp data
  timestamp_hour_onehot = pd.get_dummies(timestamp_hour).to_numpy()

  #Applying Min Max to numerical data
  scaler = MinMaxScaler()
  pressure = scaler.fit_transform(np.array(pressure).reshape(-1,1))

  #Combining Features Into One
  feature = np.concatenate([pressure, timestamp_hour_onehot],axis=1)
  X = feature[:-1]
  y = np.array(feature[5:,0]).reshape(-1,1)
  return X, y, scaler

X, y, pres_scaler = create_feature(start_period, end_period)

# %% [markdown]
# We need to shape the input further into a sequence i.e 3-dimensional numpy array. We will be using a function to return input and output sequence where each input sequence consist of 5-points observation.
#
# How:- Putting Observation of **Past 5 Hours** will be used to predict the sensor reading for the **Next 1 Hour**

# %%
def shape_sequence(arr, step, start):
  out = list()
  for i in range(start, arr.shape[0]):
    low_lim = i
    up_lim = low_lim + step
    out.append(arr[low_lim: up_lim])

    if up_lim == arr.shape[0]:
      break

  out_seq = np.array(out)
  return out_seq

#Shaping the sequence according to the length
X_seq = shape_sequence(X,5,0)
y_seq = shape_sequence(y,1,0)

#Seperating Input and Output for train and Validation
X_train, X_val, y_train, y_val = train_test_split(X_seq, y_seq, test_size=0.2, shuffle=False)

print("Training Data Shape: ", X_train.shape)
print("Validating Data Shape: ", X_val.shape)
# Out:
# Training Data Shape:  (534, 5, 25)
# Validating Data Shape:  (134, 5, 25)

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))

# import SMOTE module from imblearn library
# pip install imblearn (if you don't have imblearn in your system)
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train = np.nan_to_num(X_train)
X_train, y_train_c1 = sm.fit_resample(X_train, y_train)

print('After OverSampling, the shape of train_X: {}'.format(X_train.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train == 0)))

# %% [markdown]
# ---

# %% [markdown]
# #**Creating Prediction Model**
#
# Creating a simple 2-layer LSTM moel with input shape matching the shape of the data sequence provided.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow.keras.losses as loss
from keras.metrics import MeanAbsoluteError


def create_model(X_train, y_train, X_val, y_val):   # Added validation data as inputs
    timesteps = X_train.shape[1]  # Number of timesteps
    features = X_train.shape[2]    # Number of features in each timestep
    lstm_units = 32  # Number of units in the LSTM layers

    model = Sequential()
    model.add(LSTM(lstm_units, activation='tanh', input_shape=(timesteps, features), return_sequences=True))
    model.add(LSTM(lstm_units, activation='relu', return_sequences=True))
    model.add(LSTM(32, activation='relu', return_sequences=True))
    model.add(LSTM(16, activation='tanh', return_sequences=False))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='linear'))

    # Adding 'accuracy' to the metrics list
    model.compile(optimizer=Adam(lr=0.035), loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

    # Providing validation data to model.fit
    model.fit(X_train, y_train, validation_data=(X_val, y_val), verbose=1, epochs=1000)

    return model

model = create_model(X_train, y_train, X_val, y_val)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/1000
# 17/17 [==============================] - 7s 60ms/step - loss: 0.1565 - mean_absolute_error: 0.3645 - val_loss: 0.0757 - val_mean_absolute_error: 0.2373
# Epoch 2/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0354 - mean_absolute_error: 0.1517 - val_loss: 0.0243 - val_mean_absolute_error: 0.1216
# Epoch 3/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0223 - mean_absolute_error: 0.1175 - val_loss: 0.0229 - val_mean_absolute_error: 0.1159
# Epoch 4/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0215 - mean_absolute_error: 0.1180 - val_loss: 0.0231 - val_mean_absolute_error: 0.1162
# Epoch 5/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0209 - mean_absolute_error: 0.1137 - val_loss: 0.0227 - val_mean_absolute_error: 0.1154
# Epoch 6/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0206 - mean_absolute_error: 0.1141 - val_loss: 0.0227 - val_mean_absolute_error: 0.1151
# Epoch 7/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0205 - mean_absolute_error: 0.1136 - val_loss: 0.0227 - val_mean_absolute_error: 0.1151
# Epoch 8/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0205 - mean_absolute_error: 0.1137 - val_loss: 0.0228 - val_mean_absolute_error: 0.1157
# Epoch 9/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0206 - mean_absolute_error: 0.1144 - val_loss: 0.0226 - val_mean_absolute_error: 0.1148
# Epoch 10/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0203 - mean_absolute_error: 0.1134 - val_loss: 0.0226 - val_mean_absolute_error: 0.1149
# Epoch 11/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0204 - mean_absolute_error: 0.1133 - val_loss: 0.0226 - val_mean_absolute_error: 0.1149
# Epoch 12/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0203 - mean_absolute_error: 0.1135 - val_loss: 0.0226 - val_mean_absolute_error: 0.1148
# Epoch 13/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0203 - mean_absolute_error: 0.1130 - val_loss: 0.0228 - val_mean_absolute_error: 0.1154
# Epoch 14/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0203 - mean_absolute_error: 0.1138 - val_loss: 0.0226 - val_mean_absolute_error: 0.1147
# Epoch 15/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0202 - mean_absolute_error: 0.1133 - val_loss: 0.0226 - val_mean_absolute_error: 0.1150
# Epoch 16/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0202 - mean_absolute_error: 0.1131 - val_loss: 0.0226 - val_mean_absolute_error: 0.1152
# Epoch 17/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0202 - mean_absolute_error: 0.1135 - val_loss: 0.0227 - val_mean_absolute_error: 0.1154
# Epoch 18/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0201 - mean_absolute_error: 0.1129 - val_loss: 0.0227 - val_mean_absolute_error: 0.1154
# Epoch 19/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0202 - mean_absolute_error: 0.1134 - val_loss: 0.0232 - val_mean_absolute_error: 0.1164
# Epoch 20/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0205 - mean_absolute_error: 0.1142 - val_loss: 0.0230 - val_mean_absolute_error: 0.1163
# Epoch 21/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0214 - mean_absolute_error: 0.1168 - val_loss: 0.0227 - val_mean_absolute_error: 0.1157
# Epoch 22/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0202 - mean_absolute_error: 0.1129 - val_loss: 0.0228 - val_mean_absolute_error: 0.1157
# Epoch 23/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0203 - mean_absolute_error: 0.1134 - val_loss: 0.0234 - val_mean_absolute_error: 0.1175
# Epoch 24/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0202 - mean_absolute_error: 0.1132 - val_loss: 0.0228 - val_mean_absolute_error: 0.1156
# Epoch 25/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0202 - mean_absolute_error: 0.1138 - val_loss: 0.0228 - val_mean_absolute_error: 0.1159
# Epoch 26/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0201 - mean_absolute_error: 0.1131 - val_loss: 0.0232 - val_mean_absolute_error: 0.1165
# Epoch 27/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0202 - mean_absolute_error: 0.1139 - val_loss: 0.0229 - val_mean_absolute_error: 0.1162
# Epoch 28/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0203 - mean_absolute_error: 0.1139 - val_loss: 0.0234 - val_mean_absolute_error: 0.1169
# Epoch 29/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0202 - mean_absolute_error: 0.1134 - val_loss: 0.0230 - val_mean_absolute_error: 0.1163
# Epoch 30/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0199 - mean_absolute_error: 0.1126 - val_loss: 0.0236 - val_mean_absolute_error: 0.1179
# Epoch 31/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0200 - mean_absolute_error: 0.1139 - val_loss: 0.0230 - val_mean_absolute_error: 0.1163
# Epoch 32/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0200 - mean_absolute_error: 0.1136 - val_loss: 0.0239 - val_mean_absolute_error: 0.1181
# Epoch 33/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0202 - mean_absolute_error: 0.1136 - val_loss: 0.0230 - val_mean_absolute_error: 0.1167
# Epoch 34/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0201 - mean_absolute_error: 0.1130 - val_loss: 0.0233 - val_mean_absolute_error: 0.1176
# Epoch 35/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0196 - mean_absolute_error: 0.1121 - val_loss: 0.0230 - val_mean_absolute_error: 0.1167
# Epoch 36/1000
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0197 - mean_absolute_error: 0.1122 - val_loss: 0.0237 - val_mean_absolute_error: 0.1186
# Epoch 37/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0202 - mean_absolute_error: 0.1133 - val_loss: 0.0232 - val_mean_absolute_error: 0.1167
# Epoch 38/1000
# 17/17 [==============================] - 0s 29ms/step - loss: 0.0203 - mean_absolute_error: 0.1143 - val_loss: 0.0237 - val_mean_absolute_error: 0.1178
# Epoch 39/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0197 - mean_absolute_error: 0.1124 - val_loss: 0.0232 - val_mean_absolute_error: 0.1172
# Epoch 40/1000
# 17/17 [==============================] - 1s 34ms/step - loss: 0.0195 - mean_absolute_error: 0.1120 - val_loss: 0.0231 - val_mean_absolute_error: 0.1168
# Epoch 41/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.0197 - mean_absolute_error: 0.1128 - val_loss: 0.0232 - val_mean_absolute_error: 0.1172
# Epoch 42/1000
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0197 - mean_absolute_error: 0.1127 - val_loss: 0.0232 - val_mean_absolute_error: 0.1173
# Epoch 43/1000
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0196 - mean_absolute_error: 0.1124 - val_loss: 0.0234 - val_mean_absolute_error: 0.1180
# Epoch 44/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0197 - mean_absolute_error: 0.1122 - val_loss: 0.0232 - val_mean_absolute_error: 0.1174
# Epoch 45/1000
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0198 - mean_absolute_error: 0.1130 - val_loss: 0.0250 - val_mean_absolute_error: 0.1234
# Epoch 46/1000
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0199 - mean_absolute_error: 0.1134 - val_loss: 0.0232 - val_mean_absolute_error: 0.1174
# Epoch 47/1000
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0200 - mean_absolute_error: 0.1140 - val_loss: 0.0234 - val_mean_absolute_error: 0.1180
# Epoch 48/1000
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0193 - mean_absolute_error: 0.1113 - val_loss: 0.0232 - val_mean_absolute_error: 0.1172
# Epoch 49/1000
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0199 - mean_absolute_error: 0.1133 - val_loss: 0.0237 - val_mean_absolute_error: 0.1183
# Epoch 50/1000
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0200 - mean_absolute_error: 0.1135 - val_loss: 0.0230 - val_mean_absolute_error: 0.1168
# Epoch 51/1000
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0194 - mean_absolute_error: 0.1121 - val_loss: 0.0232 - val_mean_absolute_error: 0.1178
# Epoch 52/1000
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0196 - mean_absolute_error: 0.1123 - val_loss: 0.0233 - val_mean_absolute_error: 0.1182
# Epoch 53/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0202 - mean_absolute_error: 0.1140 - val_loss: 0.0233 - val_mean_absolute_error: 0.1181
# Epoch 54/1000
# 17/17 [==============================] - 0s 26ms/step - loss: 0.0195 - mean_absolute_error: 0.1116 - val_loss: 0.0250 - val_mean_absolute_error: 0.1236
# Epoch 55/1000
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0198 - mean_absolute_error: 0.1125 - val_loss: 0.0237 - val_mean_absolute_error: 0.1193
# Epoch 56/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0200 - mean_absolute_error: 0.1133 - val_loss: 0.0234 - val_mean_absolute_error: 0.1182
# Epoch 57/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0194 - mean_absolute_error: 0.1114 - val_loss: 0.0236 - val_mean_absolute_error: 0.1181
# Epoch 58/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0201 - mean_absolute_error: 0.1136 - val_loss: 0.0232 - val_mean_absolute_error: 0.1174
# Epoch 59/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0199 - mean_absolute_error: 0.1121 - val_loss: 0.0244 - val_mean_absolute_error: 0.1216
# Epoch 60/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0190 - mean_absolute_error: 0.1110 - val_loss: 0.0236 - val_mean_absolute_error: 0.1186
# Epoch 61/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0194 - mean_absolute_error: 0.1117 - val_loss: 0.0232 - val_mean_absolute_error: 0.1178
# Epoch 62/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0191 - mean_absolute_error: 0.1107 - val_loss: 0.0233 - val_mean_absolute_error: 0.1184
# Epoch 63/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0191 - mean_absolute_error: 0.1108 - val_loss: 0.0235 - val_mean_absolute_error: 0.1189
# Epoch 64/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0204 - mean_absolute_error: 0.1137 - val_loss: 0.0236 - val_mean_absolute_error: 0.1195
# Epoch 65/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0197 - mean_absolute_error: 0.1119 - val_loss: 0.0245 - val_mean_absolute_error: 0.1219
# Epoch 66/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0191 - mean_absolute_error: 0.1112 - val_loss: 0.0233 - val_mean_absolute_error: 0.1182
# Epoch 67/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0191 - mean_absolute_error: 0.1108 - val_loss: 0.0234 - val_mean_absolute_error: 0.1184
# Epoch 68/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0191 - mean_absolute_error: 0.1107 - val_loss: 0.0233 - val_mean_absolute_error: 0.1182
# Epoch 69/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0191 - mean_absolute_error: 0.1110 - val_loss: 0.0236 - val_mean_absolute_error: 0.1197
# Epoch 70/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0191 - mean_absolute_error: 0.1107 - val_loss: 0.0237 - val_mean_absolute_error: 0.1199
# Epoch 71/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0190 - mean_absolute_error: 0.1105 - val_loss: 0.0234 - val_mean_absolute_error: 0.1185
# Epoch 72/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0192 - mean_absolute_error: 0.1103 - val_loss: 0.0236 - val_mean_absolute_error: 0.1190
# Epoch 73/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0189 - mean_absolute_error: 0.1101 - val_loss: 0.0238 - val_mean_absolute_error: 0.1202
# Epoch 74/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0189 - mean_absolute_error: 0.1102 - val_loss: 0.0234 - val_mean_absolute_error: 0.1188
# Epoch 75/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0192 - mean_absolute_error: 0.1112 - val_loss: 0.0236 - val_mean_absolute_error: 0.1195
# Epoch 76/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0188 - mean_absolute_error: 0.1100 - val_loss: 0.0241 - val_mean_absolute_error: 0.1212
# Epoch 77/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0190 - mean_absolute_error: 0.1107 - val_loss: 0.0234 - val_mean_absolute_error: 0.1192
# Epoch 78/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0194 - mean_absolute_error: 0.1110 - val_loss: 0.0236 - val_mean_absolute_error: 0.1191
# Epoch 79/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0191 - mean_absolute_error: 0.1113 - val_loss: 0.0234 - val_mean_absolute_error: 0.1184
# Epoch 80/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0189 - mean_absolute_error: 0.1099 - val_loss: 0.0234 - val_mean_absolute_error: 0.1189
# Epoch 81/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0192 - mean_absolute_error: 0.1108 - val_loss: 0.0242 - val_mean_absolute_error: 0.1219
# Epoch 82/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0194 - mean_absolute_error: 0.1111 - val_loss: 0.0235 - val_mean_absolute_error: 0.1194
# Epoch 83/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0190 - mean_absolute_error: 0.1104 - val_loss: 0.0233 - val_mean_absolute_error: 0.1183
# Epoch 84/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0189 - mean_absolute_error: 0.1100 - val_loss: 0.0236 - val_mean_absolute_error: 0.1199
# Epoch 85/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0188 - mean_absolute_error: 0.1095 - val_loss: 0.0239 - val_mean_absolute_error: 0.1208
# Epoch 86/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0190 - mean_absolute_error: 0.1106 - val_loss: 0.0239 - val_mean_absolute_error: 0.1205
# Epoch 87/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0191 - mean_absolute_error: 0.1112 - val_loss: 0.0235 - val_mean_absolute_error: 0.1195
# Epoch 88/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0188 - mean_absolute_error: 0.1103 - val_loss: 0.0238 - val_mean_absolute_error: 0.1200
# Epoch 89/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0185 - mean_absolute_error: 0.1088 - val_loss: 0.0239 - val_mean_absolute_error: 0.1204
# Epoch 90/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0186 - mean_absolute_error: 0.1095 - val_loss: 0.0234 - val_mean_absolute_error: 0.1192
# Epoch 91/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0185 - mean_absolute_error: 0.1090 - val_loss: 0.0239 - val_mean_absolute_error: 0.1212
# Epoch 92/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0188 - mean_absolute_error: 0.1097 - val_loss: 0.0256 - val_mean_absolute_error: 0.1268
# Epoch 93/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0190 - mean_absolute_error: 0.1112 - val_loss: 0.0238 - val_mean_absolute_error: 0.1201
# Epoch 94/1000
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0185 - mean_absolute_error: 0.1090 - val_loss: 0.0235 - val_mean_absolute_error: 0.1190
# Epoch 95/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0184 - mean_absolute_error: 0.1086 - val_loss: 0.0236 - val_mean_absolute_error: 0.1194
# Epoch 96/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0185 - mean_absolute_error: 0.1090 - val_loss: 0.0237 - val_mean_absolute_error: 0.1198
# Epoch 97/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0185 - mean_absolute_error: 0.1088 - val_loss: 0.0237 - val_mean_absolute_error: 0.1201
# Epoch 98/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0193 - mean_absolute_error: 0.1113 - val_loss: 0.0236 - val_mean_absolute_error: 0.1200
# Epoch 99/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0190 - mean_absolute_error: 0.1095 - val_loss: 0.0235 - val_mean_absolute_error: 0.1192
# Epoch 100/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0186 - mean_absolute_error: 0.1091 - val_loss: 0.0244 - val_mean_absolute_error: 0.1225
# Epoch 101/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0184 - mean_absolute_error: 0.1093 - val_loss: 0.0236 - val_mean_absolute_error: 0.1193
# Epoch 102/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0184 - mean_absolute_error: 0.1083 - val_loss: 0.0236 - val_mean_absolute_error: 0.1200
# Epoch 103/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0183 - mean_absolute_error: 0.1085 - val_loss: 0.0237 - val_mean_absolute_error: 0.1196
# Epoch 104/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0183 - mean_absolute_error: 0.1086 - val_loss: 0.0236 - val_mean_absolute_error: 0.1195
# Epoch 105/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0184 - mean_absolute_error: 0.1083 - val_loss: 0.0262 - val_mean_absolute_error: 0.1254
# Epoch 106/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0191 - mean_absolute_error: 0.1090 - val_loss: 0.0237 - val_mean_absolute_error: 0.1197
# Epoch 107/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0185 - mean_absolute_error: 0.1093 - val_loss: 0.0235 - val_mean_absolute_error: 0.1196
# Epoch 108/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0183 - mean_absolute_error: 0.1080 - val_loss: 0.0235 - val_mean_absolute_error: 0.1191
# Epoch 109/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0187 - mean_absolute_error: 0.1093 - val_loss: 0.0243 - val_mean_absolute_error: 0.1211
# Epoch 110/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0186 - mean_absolute_error: 0.1093 - val_loss: 0.0240 - val_mean_absolute_error: 0.1209
# Epoch 111/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0181 - mean_absolute_error: 0.1081 - val_loss: 0.0236 - val_mean_absolute_error: 0.1196
# Epoch 112/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0179 - mean_absolute_error: 0.1071 - val_loss: 0.0237 - val_mean_absolute_error: 0.1200
# Epoch 113/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0179 - mean_absolute_error: 0.1071 - val_loss: 0.0242 - val_mean_absolute_error: 0.1216
# Epoch 114/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0182 - mean_absolute_error: 0.1081 - val_loss: 0.0247 - val_mean_absolute_error: 0.1238
# Epoch 115/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0189 - mean_absolute_error: 0.1090 - val_loss: 0.0243 - val_mean_absolute_error: 0.1220
# Epoch 116/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0181 - mean_absolute_error: 0.1078 - val_loss: 0.0237 - val_mean_absolute_error: 0.1201
# Epoch 117/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0184 - mean_absolute_error: 0.1083 - val_loss: 0.0236 - val_mean_absolute_error: 0.1196
# Epoch 118/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0184 - mean_absolute_error: 0.1081 - val_loss: 0.0239 - val_mean_absolute_error: 0.1206
# Epoch 119/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0181 - mean_absolute_error: 0.1078 - val_loss: 0.0240 - val_mean_absolute_error: 0.1212
# Epoch 120/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0179 - mean_absolute_error: 0.1073 - val_loss: 0.0248 - val_mean_absolute_error: 0.1233
# Epoch 121/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0178 - mean_absolute_error: 0.1066 - val_loss: 0.0239 - val_mean_absolute_error: 0.1205
# Epoch 122/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0180 - mean_absolute_error: 0.1078 - val_loss: 0.0238 - val_mean_absolute_error: 0.1201
# Epoch 123/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0181 - mean_absolute_error: 0.1078 - val_loss: 0.0243 - val_mean_absolute_error: 0.1218
# Epoch 124/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0182 - mean_absolute_error: 0.1088 - val_loss: 0.0236 - val_mean_absolute_error: 0.1193
# Epoch 125/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0183 - mean_absolute_error: 0.1093 - val_loss: 0.0240 - val_mean_absolute_error: 0.1208
# Epoch 126/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0180 - mean_absolute_error: 0.1075 - val_loss: 0.0240 - val_mean_absolute_error: 0.1211
# Epoch 127/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0179 - mean_absolute_error: 0.1072 - val_loss: 0.0241 - val_mean_absolute_error: 0.1217
# Epoch 128/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0183 - mean_absolute_error: 0.1094 - val_loss: 0.0254 - val_mean_absolute_error: 0.1261
# Epoch 129/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0183 - mean_absolute_error: 0.1083 - val_loss: 0.0252 - val_mean_absolute_error: 0.1250
# Epoch 130/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0181 - mean_absolute_error: 0.1078 - val_loss: 0.0239 - val_mean_absolute_error: 0.1202
# Epoch 131/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0183 - mean_absolute_error: 0.1081 - val_loss: 0.0266 - val_mean_absolute_error: 0.1302
# Epoch 132/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0181 - mean_absolute_error: 0.1075 - val_loss: 0.0240 - val_mean_absolute_error: 0.1211
# Epoch 133/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0179 - mean_absolute_error: 0.1069 - val_loss: 0.0237 - val_mean_absolute_error: 0.1198
# Epoch 134/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0175 - mean_absolute_error: 0.1060 - val_loss: 0.0241 - val_mean_absolute_error: 0.1210
# Epoch 135/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0176 - mean_absolute_error: 0.1065 - val_loss: 0.0246 - val_mean_absolute_error: 0.1223
# Epoch 136/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0178 - mean_absolute_error: 0.1068 - val_loss: 0.0246 - val_mean_absolute_error: 0.1224
# Epoch 137/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0175 - mean_absolute_error: 0.1063 - val_loss: 0.0258 - val_mean_absolute_error: 0.1266
# Epoch 138/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0178 - mean_absolute_error: 0.1064 - val_loss: 0.0243 - val_mean_absolute_error: 0.1214
# Epoch 139/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0174 - mean_absolute_error: 0.1059 - val_loss: 0.0248 - val_mean_absolute_error: 0.1233
# Epoch 140/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0173 - mean_absolute_error: 0.1049 - val_loss: 0.0250 - val_mean_absolute_error: 0.1235
# Epoch 141/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0175 - mean_absolute_error: 0.1060 - val_loss: 0.0245 - val_mean_absolute_error: 0.1222
# Epoch 142/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0175 - mean_absolute_error: 0.1056 - val_loss: 0.0245 - val_mean_absolute_error: 0.1221
# Epoch 143/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0176 - mean_absolute_error: 0.1067 - val_loss: 0.0246 - val_mean_absolute_error: 0.1220
# Epoch 144/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0175 - mean_absolute_error: 0.1054 - val_loss: 0.0240 - val_mean_absolute_error: 0.1203
# Epoch 145/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0175 - mean_absolute_error: 0.1061 - val_loss: 0.0248 - val_mean_absolute_error: 0.1227
# Epoch 146/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0175 - mean_absolute_error: 0.1067 - val_loss: 0.0244 - val_mean_absolute_error: 0.1219
# Epoch 147/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0175 - mean_absolute_error: 0.1054 - val_loss: 0.0244 - val_mean_absolute_error: 0.1215
# Epoch 148/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0172 - mean_absolute_error: 0.1048 - val_loss: 0.0253 - val_mean_absolute_error: 0.1250
# Epoch 149/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0177 - mean_absolute_error: 0.1064 - val_loss: 0.0249 - val_mean_absolute_error: 0.1233
# Epoch 150/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0177 - mean_absolute_error: 0.1064 - val_loss: 0.0248 - val_mean_absolute_error: 0.1233
# Epoch 151/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0172 - mean_absolute_error: 0.1046 - val_loss: 0.0252 - val_mean_absolute_error: 0.1237
# Epoch 152/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0177 - mean_absolute_error: 0.1063 - val_loss: 0.0249 - val_mean_absolute_error: 0.1228
# Epoch 153/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0173 - mean_absolute_error: 0.1052 - val_loss: 0.0251 - val_mean_absolute_error: 0.1234
# Epoch 154/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0170 - mean_absolute_error: 0.1048 - val_loss: 0.0250 - val_mean_absolute_error: 0.1225
# Epoch 155/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0170 - mean_absolute_error: 0.1044 - val_loss: 0.0254 - val_mean_absolute_error: 0.1239
# Epoch 156/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0171 - mean_absolute_error: 0.1040 - val_loss: 0.0258 - val_mean_absolute_error: 0.1243
# Epoch 157/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0170 - mean_absolute_error: 0.1037 - val_loss: 0.0252 - val_mean_absolute_error: 0.1233
# Epoch 158/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0173 - mean_absolute_error: 0.1050 - val_loss: 0.0279 - val_mean_absolute_error: 0.1313
# Epoch 159/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0171 - mean_absolute_error: 0.1046 - val_loss: 0.0254 - val_mean_absolute_error: 0.1243
# Epoch 160/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0176 - mean_absolute_error: 0.1063 - val_loss: 0.0265 - val_mean_absolute_error: 0.1262
# Epoch 161/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0181 - mean_absolute_error: 0.1070 - val_loss: 0.0246 - val_mean_absolute_error: 0.1216
# Epoch 162/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0172 - mean_absolute_error: 0.1047 - val_loss: 0.0254 - val_mean_absolute_error: 0.1235
# Epoch 163/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0175 - mean_absolute_error: 0.1060 - val_loss: 0.0243 - val_mean_absolute_error: 0.1207
# Epoch 164/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0169 - mean_absolute_error: 0.1040 - val_loss: 0.0258 - val_mean_absolute_error: 0.1244
# Epoch 165/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0170 - mean_absolute_error: 0.1033 - val_loss: 0.0252 - val_mean_absolute_error: 0.1233
# Epoch 166/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0166 - mean_absolute_error: 0.1033 - val_loss: 0.0260 - val_mean_absolute_error: 0.1241
# Epoch 167/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0173 - mean_absolute_error: 0.1049 - val_loss: 0.0256 - val_mean_absolute_error: 0.1243
# Epoch 168/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0178 - mean_absolute_error: 0.1054 - val_loss: 0.0249 - val_mean_absolute_error: 0.1221
# Epoch 169/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0172 - mean_absolute_error: 0.1037 - val_loss: 0.0249 - val_mean_absolute_error: 0.1219
# Epoch 170/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0168 - mean_absolute_error: 0.1034 - val_loss: 0.0261 - val_mean_absolute_error: 0.1242
# Epoch 171/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0169 - mean_absolute_error: 0.1038 - val_loss: 0.0253 - val_mean_absolute_error: 0.1220
# Epoch 172/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0167 - mean_absolute_error: 0.1032 - val_loss: 0.0252 - val_mean_absolute_error: 0.1223
# Epoch 173/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0167 - mean_absolute_error: 0.1028 - val_loss: 0.0255 - val_mean_absolute_error: 0.1232
# Epoch 174/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0166 - mean_absolute_error: 0.1029 - val_loss: 0.0278 - val_mean_absolute_error: 0.1298
# Epoch 175/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0172 - mean_absolute_error: 0.1051 - val_loss: 0.0268 - val_mean_absolute_error: 0.1266
# Epoch 176/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0167 - mean_absolute_error: 0.1033 - val_loss: 0.0255 - val_mean_absolute_error: 0.1221
# Epoch 177/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0167 - mean_absolute_error: 0.1021 - val_loss: 0.0254 - val_mean_absolute_error: 0.1230
# Epoch 178/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0164 - mean_absolute_error: 0.1025 - val_loss: 0.0268 - val_mean_absolute_error: 0.1257
# Epoch 179/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0170 - mean_absolute_error: 0.1038 - val_loss: 0.0254 - val_mean_absolute_error: 0.1224
# Epoch 180/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0166 - mean_absolute_error: 0.1026 - val_loss: 0.0264 - val_mean_absolute_error: 0.1244
# Epoch 181/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0161 - mean_absolute_error: 0.1013 - val_loss: 0.0272 - val_mean_absolute_error: 0.1276
# Epoch 182/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0166 - mean_absolute_error: 0.1033 - val_loss: 0.0262 - val_mean_absolute_error: 0.1247
# Epoch 183/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0163 - mean_absolute_error: 0.1017 - val_loss: 0.0259 - val_mean_absolute_error: 0.1249
# Epoch 184/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0169 - mean_absolute_error: 0.1030 - val_loss: 0.0251 - val_mean_absolute_error: 0.1226
# Epoch 185/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0167 - mean_absolute_error: 0.1026 - val_loss: 0.0258 - val_mean_absolute_error: 0.1240
# Epoch 186/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0165 - mean_absolute_error: 0.1025 - val_loss: 0.0256 - val_mean_absolute_error: 0.1237
# Epoch 187/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0162 - mean_absolute_error: 0.1003 - val_loss: 0.0259 - val_mean_absolute_error: 0.1237
# Epoch 188/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0161 - mean_absolute_error: 0.1015 - val_loss: 0.0264 - val_mean_absolute_error: 0.1248
# Epoch 189/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0166 - mean_absolute_error: 0.1022 - val_loss: 0.0268 - val_mean_absolute_error: 0.1261
# Epoch 190/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0161 - mean_absolute_error: 0.1005 - val_loss: 0.0263 - val_mean_absolute_error: 0.1238
# Epoch 191/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0164 - mean_absolute_error: 0.1014 - val_loss: 0.0268 - val_mean_absolute_error: 0.1263
# Epoch 192/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0162 - mean_absolute_error: 0.1020 - val_loss: 0.0264 - val_mean_absolute_error: 0.1252
# Epoch 193/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0159 - mean_absolute_error: 0.1002 - val_loss: 0.0280 - val_mean_absolute_error: 0.1282
# Epoch 194/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0157 - mean_absolute_error: 0.0997 - val_loss: 0.0287 - val_mean_absolute_error: 0.1311
# Epoch 195/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0163 - mean_absolute_error: 0.1012 - val_loss: 0.0263 - val_mean_absolute_error: 0.1254
# Epoch 196/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0164 - mean_absolute_error: 0.1015 - val_loss: 0.0308 - val_mean_absolute_error: 0.1337
# Epoch 197/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0169 - mean_absolute_error: 0.1042 - val_loss: 0.0250 - val_mean_absolute_error: 0.1232
# Epoch 198/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0165 - mean_absolute_error: 0.1007 - val_loss: 0.0265 - val_mean_absolute_error: 0.1265
# Epoch 199/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0166 - mean_absolute_error: 0.1021 - val_loss: 0.0252 - val_mean_absolute_error: 0.1225
# Epoch 200/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0157 - mean_absolute_error: 0.0993 - val_loss: 0.0275 - val_mean_absolute_error: 0.1279
# Epoch 201/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0161 - mean_absolute_error: 0.1004 - val_loss: 0.0263 - val_mean_absolute_error: 0.1249
# Epoch 202/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0155 - mean_absolute_error: 0.0980 - val_loss: 0.0272 - val_mean_absolute_error: 0.1266
# Epoch 203/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0156 - mean_absolute_error: 0.0992 - val_loss: 0.0272 - val_mean_absolute_error: 0.1273
# Epoch 204/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0154 - mean_absolute_error: 0.0980 - val_loss: 0.0270 - val_mean_absolute_error: 0.1258
# Epoch 205/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0155 - mean_absolute_error: 0.0980 - val_loss: 0.0280 - val_mean_absolute_error: 0.1283
# Epoch 206/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0152 - mean_absolute_error: 0.0969 - val_loss: 0.0292 - val_mean_absolute_error: 0.1309
# Epoch 207/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0153 - mean_absolute_error: 0.0975 - val_loss: 0.0284 - val_mean_absolute_error: 0.1292
# Epoch 208/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0153 - mean_absolute_error: 0.0978 - val_loss: 0.0289 - val_mean_absolute_error: 0.1312
# Epoch 209/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0152 - mean_absolute_error: 0.0972 - val_loss: 0.0272 - val_mean_absolute_error: 0.1268
# Epoch 210/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0154 - mean_absolute_error: 0.0978 - val_loss: 0.0303 - val_mean_absolute_error: 0.1341
# Epoch 211/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0153 - mean_absolute_error: 0.0977 - val_loss: 0.0275 - val_mean_absolute_error: 0.1276
# Epoch 212/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0153 - mean_absolute_error: 0.0981 - val_loss: 0.0273 - val_mean_absolute_error: 0.1275
# Epoch 213/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0151 - mean_absolute_error: 0.0972 - val_loss: 0.0301 - val_mean_absolute_error: 0.1325
# Epoch 214/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0151 - mean_absolute_error: 0.0963 - val_loss: 0.0285 - val_mean_absolute_error: 0.1302
# Epoch 215/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0148 - mean_absolute_error: 0.0956 - val_loss: 0.0318 - val_mean_absolute_error: 0.1355
# Epoch 216/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0149 - mean_absolute_error: 0.0960 - val_loss: 0.0317 - val_mean_absolute_error: 0.1384
# Epoch 217/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0158 - mean_absolute_error: 0.0998 - val_loss: 0.0309 - val_mean_absolute_error: 0.1353
# Epoch 218/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0149 - mean_absolute_error: 0.0961 - val_loss: 0.0302 - val_mean_absolute_error: 0.1331
# Epoch 219/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0150 - mean_absolute_error: 0.0964 - val_loss: 0.0288 - val_mean_absolute_error: 0.1302
# Epoch 220/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0148 - mean_absolute_error: 0.0958 - val_loss: 0.0274 - val_mean_absolute_error: 0.1290
# Epoch 221/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0147 - mean_absolute_error: 0.0953 - val_loss: 0.0282 - val_mean_absolute_error: 0.1292
# Epoch 222/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0150 - mean_absolute_error: 0.0967 - val_loss: 0.0314 - val_mean_absolute_error: 0.1342
# Epoch 223/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0148 - mean_absolute_error: 0.0951 - val_loss: 0.0282 - val_mean_absolute_error: 0.1308
# Epoch 224/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0147 - mean_absolute_error: 0.0943 - val_loss: 0.0275 - val_mean_absolute_error: 0.1274
# Epoch 225/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0148 - mean_absolute_error: 0.0968 - val_loss: 0.0298 - val_mean_absolute_error: 0.1326
# Epoch 226/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0145 - mean_absolute_error: 0.0944 - val_loss: 0.0306 - val_mean_absolute_error: 0.1343
# Epoch 227/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0145 - mean_absolute_error: 0.0946 - val_loss: 0.0313 - val_mean_absolute_error: 0.1335
# Epoch 228/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0149 - mean_absolute_error: 0.0964 - val_loss: 0.0292 - val_mean_absolute_error: 0.1328
# Epoch 229/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0153 - mean_absolute_error: 0.0981 - val_loss: 0.0282 - val_mean_absolute_error: 0.1294
# Epoch 230/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0147 - mean_absolute_error: 0.0951 - val_loss: 0.0303 - val_mean_absolute_error: 0.1332
# Epoch 231/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0143 - mean_absolute_error: 0.0929 - val_loss: 0.0320 - val_mean_absolute_error: 0.1352
# Epoch 232/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0142 - mean_absolute_error: 0.0932 - val_loss: 0.0272 - val_mean_absolute_error: 0.1293
# Epoch 233/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0143 - mean_absolute_error: 0.0930 - val_loss: 0.0310 - val_mean_absolute_error: 0.1363
# Epoch 234/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0142 - mean_absolute_error: 0.0932 - val_loss: 0.0341 - val_mean_absolute_error: 0.1398
# Epoch 235/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0141 - mean_absolute_error: 0.0929 - val_loss: 0.0293 - val_mean_absolute_error: 0.1338
# Epoch 236/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0140 - mean_absolute_error: 0.0928 - val_loss: 0.0314 - val_mean_absolute_error: 0.1354
# Epoch 237/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0146 - mean_absolute_error: 0.0959 - val_loss: 0.0300 - val_mean_absolute_error: 0.1317
# Epoch 238/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0144 - mean_absolute_error: 0.0938 - val_loss: 0.0287 - val_mean_absolute_error: 0.1313
# Epoch 239/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0143 - mean_absolute_error: 0.0921 - val_loss: 0.0301 - val_mean_absolute_error: 0.1324
# Epoch 240/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0137 - mean_absolute_error: 0.0916 - val_loss: 0.0290 - val_mean_absolute_error: 0.1314
# Epoch 241/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0137 - mean_absolute_error: 0.0913 - val_loss: 0.0296 - val_mean_absolute_error: 0.1322
# Epoch 242/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0147 - mean_absolute_error: 0.0950 - val_loss: 0.0271 - val_mean_absolute_error: 0.1273
# Epoch 243/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0140 - mean_absolute_error: 0.0917 - val_loss: 0.0335 - val_mean_absolute_error: 0.1365
# Epoch 244/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0142 - mean_absolute_error: 0.0929 - val_loss: 0.0296 - val_mean_absolute_error: 0.1319
# Epoch 245/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0137 - mean_absolute_error: 0.0918 - val_loss: 0.0301 - val_mean_absolute_error: 0.1312
# Epoch 246/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0137 - mean_absolute_error: 0.0912 - val_loss: 0.0296 - val_mean_absolute_error: 0.1320
# Epoch 247/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0136 - mean_absolute_error: 0.0897 - val_loss: 0.0322 - val_mean_absolute_error: 0.1345
# Epoch 248/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0139 - mean_absolute_error: 0.0920 - val_loss: 0.0361 - val_mean_absolute_error: 0.1427
# Epoch 249/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0141 - mean_absolute_error: 0.0924 - val_loss: 0.0313 - val_mean_absolute_error: 0.1345
# Epoch 250/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0137 - mean_absolute_error: 0.0907 - val_loss: 0.0317 - val_mean_absolute_error: 0.1361
# Epoch 251/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0134 - mean_absolute_error: 0.0900 - val_loss: 0.0359 - val_mean_absolute_error: 0.1414
# Epoch 252/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0132 - mean_absolute_error: 0.0894 - val_loss: 0.0302 - val_mean_absolute_error: 0.1343
# Epoch 253/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0131 - mean_absolute_error: 0.0881 - val_loss: 0.0351 - val_mean_absolute_error: 0.1410
# Epoch 254/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0136 - mean_absolute_error: 0.0901 - val_loss: 0.0339 - val_mean_absolute_error: 0.1403
# Epoch 255/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0138 - mean_absolute_error: 0.0908 - val_loss: 0.0310 - val_mean_absolute_error: 0.1332
# Epoch 256/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0129 - mean_absolute_error: 0.0881 - val_loss: 0.0351 - val_mean_absolute_error: 0.1433
# Epoch 257/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0133 - mean_absolute_error: 0.0888 - val_loss: 0.0354 - val_mean_absolute_error: 0.1412
# Epoch 258/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0138 - mean_absolute_error: 0.0908 - val_loss: 0.0399 - val_mean_absolute_error: 0.1491
# Epoch 259/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0137 - mean_absolute_error: 0.0914 - val_loss: 0.0300 - val_mean_absolute_error: 0.1323
# Epoch 260/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0133 - mean_absolute_error: 0.0900 - val_loss: 0.0313 - val_mean_absolute_error: 0.1349
# Epoch 261/1000
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0131 - mean_absolute_error: 0.0890 - val_loss: 0.0302 - val_mean_absolute_error: 0.1333
# Epoch 262/1000
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0137 - mean_absolute_error: 0.0910 - val_loss: 0.0322 - val_mean_absolute_error: 0.1380
# Epoch 263/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0133 - mean_absolute_error: 0.0880 - val_loss: 0.0301 - val_mean_absolute_error: 0.1332
# Epoch 264/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0127 - mean_absolute_error: 0.0873 - val_loss: 0.0335 - val_mean_absolute_error: 0.1380
# Epoch 265/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0125 - mean_absolute_error: 0.0871 - val_loss: 0.0313 - val_mean_absolute_error: 0.1344
# Epoch 266/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0127 - mean_absolute_error: 0.0866 - val_loss: 0.0337 - val_mean_absolute_error: 0.1372
# Epoch 267/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0128 - mean_absolute_error: 0.0870 - val_loss: 0.0319 - val_mean_absolute_error: 0.1371
# Epoch 268/1000
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0125 - mean_absolute_error: 0.0862 - val_loss: 0.0360 - val_mean_absolute_error: 0.1426
# Epoch 269/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0130 - mean_absolute_error: 0.0880 - val_loss: 0.0339 - val_mean_absolute_error: 0.1384
# Epoch 270/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0127 - mean_absolute_error: 0.0866 - val_loss: 0.0318 - val_mean_absolute_error: 0.1358
# Epoch 271/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0128 - mean_absolute_error: 0.0871 - val_loss: 0.0330 - val_mean_absolute_error: 0.1373
# Epoch 272/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0126 - mean_absolute_error: 0.0872 - val_loss: 0.0323 - val_mean_absolute_error: 0.1363
# Epoch 273/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0125 - mean_absolute_error: 0.0864 - val_loss: 0.0341 - val_mean_absolute_error: 0.1399
# Epoch 274/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0122 - mean_absolute_error: 0.0856 - val_loss: 0.0356 - val_mean_absolute_error: 0.1409
# Epoch 275/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0130 - mean_absolute_error: 0.0885 - val_loss: 0.0331 - val_mean_absolute_error: 0.1413
# Epoch 276/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0129 - mean_absolute_error: 0.0881 - val_loss: 0.0339 - val_mean_absolute_error: 0.1392
# Epoch 277/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0125 - mean_absolute_error: 0.0861 - val_loss: 0.0323 - val_mean_absolute_error: 0.1364
# Epoch 278/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0121 - mean_absolute_error: 0.0834 - val_loss: 0.0347 - val_mean_absolute_error: 0.1436
# Epoch 279/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0122 - mean_absolute_error: 0.0841 - val_loss: 0.0324 - val_mean_absolute_error: 0.1366
# Epoch 280/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0124 - mean_absolute_error: 0.0865 - val_loss: 0.0296 - val_mean_absolute_error: 0.1330
# Epoch 281/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0132 - mean_absolute_error: 0.0900 - val_loss: 0.0311 - val_mean_absolute_error: 0.1341
# Epoch 282/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0128 - mean_absolute_error: 0.0883 - val_loss: 0.0313 - val_mean_absolute_error: 0.1345
# Epoch 283/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0131 - mean_absolute_error: 0.0885 - val_loss: 0.0303 - val_mean_absolute_error: 0.1339
# Epoch 284/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0132 - mean_absolute_error: 0.0897 - val_loss: 0.0308 - val_mean_absolute_error: 0.1337
# Epoch 285/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0128 - mean_absolute_error: 0.0877 - val_loss: 0.0304 - val_mean_absolute_error: 0.1362
# Epoch 286/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0122 - mean_absolute_error: 0.0840 - val_loss: 0.0342 - val_mean_absolute_error: 0.1408
# Epoch 287/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0120 - mean_absolute_error: 0.0837 - val_loss: 0.0345 - val_mean_absolute_error: 0.1411
# Epoch 288/1000
# ...
# Epoch 914/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0355 - val_mean_absolute_error: 0.1439
# Epoch 915/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0370 - val_loss: 0.0367 - val_mean_absolute_error: 0.1501
# Epoch 916/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0338 - val_loss: 0.0391 - val_mean_absolute_error: 0.1525
# Epoch 917/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0299 - val_loss: 0.0391 - val_mean_absolute_error: 0.1523
# Epoch 918/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0295 - val_loss: 0.0378 - val_mean_absolute_error: 0.1513
# Epoch 919/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0278 - val_loss: 0.0396 - val_mean_absolute_error: 0.1529
# Epoch 920/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0257 - val_loss: 0.0403 - val_mean_absolute_error: 0.1569
# Epoch 921/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0287 - val_loss: 0.0401 - val_mean_absolute_error: 0.1535
# Epoch 922/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0282 - val_loss: 0.0399 - val_mean_absolute_error: 0.1558
# Epoch 923/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0256 - val_loss: 0.0392 - val_mean_absolute_error: 0.1538
# Epoch 924/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0252 - val_loss: 0.0408 - val_mean_absolute_error: 0.1573
# Epoch 925/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0268 - val_loss: 0.0407 - val_mean_absolute_error: 0.1567
# Epoch 926/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0275 - val_loss: 0.0395 - val_mean_absolute_error: 0.1525
# Epoch 927/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0276 - val_loss: 0.0392 - val_mean_absolute_error: 0.1548
# Epoch 928/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0252 - val_loss: 0.0383 - val_mean_absolute_error: 0.1522
# Epoch 929/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0015 - mean_absolute_error: 0.0240 - val_loss: 0.0376 - val_mean_absolute_error: 0.1490
# Epoch 930/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0253 - val_loss: 0.0396 - val_mean_absolute_error: 0.1523
# Epoch 931/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0256 - val_loss: 0.0378 - val_mean_absolute_error: 0.1499
# Epoch 932/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0250 - val_loss: 0.0388 - val_mean_absolute_error: 0.1526
# Epoch 933/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0242 - val_loss: 0.0407 - val_mean_absolute_error: 0.1558
# Epoch 934/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0234 - val_loss: 0.0393 - val_mean_absolute_error: 0.1530
# Epoch 935/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0264 - val_loss: 0.0384 - val_mean_absolute_error: 0.1525
# Epoch 936/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0261 - val_loss: 0.0412 - val_mean_absolute_error: 0.1574
# Epoch 937/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0238 - val_loss: 0.0384 - val_mean_absolute_error: 0.1488
# Epoch 938/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0272 - val_loss: 0.0397 - val_mean_absolute_error: 0.1534
# Epoch 939/1000
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0014 - mean_absolute_error: 0.0254 - val_loss: 0.0368 - val_mean_absolute_error: 0.1477
# Epoch 940/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0016 - mean_absolute_error: 0.0272 - val_loss: 0.0385 - val_mean_absolute_error: 0.1513
# Epoch 941/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0295 - val_loss: 0.0382 - val_mean_absolute_error: 0.1522
# Epoch 942/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0274 - val_loss: 0.0413 - val_mean_absolute_error: 0.1570
# Epoch 943/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0263 - val_loss: 0.0396 - val_mean_absolute_error: 0.1552
# Epoch 944/1000
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0015 - mean_absolute_error: 0.0255 - val_loss: 0.0398 - val_mean_absolute_error: 0.1540
# Epoch 945/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0244 - val_loss: 0.0416 - val_mean_absolute_error: 0.1577
# Epoch 946/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0243 - val_loss: 0.0401 - val_mean_absolute_error: 0.1545
# Epoch 947/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0263 - val_loss: 0.0384 - val_mean_absolute_error: 0.1524
# Epoch 948/1000
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0278 - val_loss: 0.0378 - val_mean_absolute_error: 0.1504
# Epoch 949/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0023 - mean_absolute_error: 0.0319 - val_loss: 0.0399 - val_mean_absolute_error: 0.1553
# Epoch 950/1000
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0296 - val_loss: 0.0386 - val_mean_absolute_error: 0.1530
# Epoch 951/1000
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0283 - val_loss: 0.0379 - val_mean_absolute_error: 0.1512
# Epoch 952/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0024 - mean_absolute_error: 0.0321 - val_loss: 0.0353 - val_mean_absolute_error: 0.1432
# Epoch 953/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_absolute_error: 0.0295 - val_loss: 0.0371 - val_mean_absolute_error: 0.1489
# Epoch 954/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0291 - val_loss: 0.0374 - val_mean_absolute_error: 0.1498
# Epoch 955/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_absolute_error: 0.0308 - val_loss: 0.0401 - val_mean_absolute_error: 0.1556
# Epoch 956/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0021 - mean_absolute_error: 0.0312 - val_loss: 0.0384 - val_mean_absolute_error: 0.1509
# Epoch 957/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0020 - mean_absolute_error: 0.0309 - val_loss: 0.0379 - val_mean_absolute_error: 0.1510
# Epoch 958/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0020 - mean_absolute_error: 0.0313 - val_loss: 0.0409 - val_mean_absolute_error: 0.1576
# Epoch 959/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0018 - mean_absolute_error: 0.0293 - val_loss: 0.0398 - val_mean_absolute_error: 0.1559
# Epoch 960/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0278 - val_loss: 0.0423 - val_mean_absolute_error: 0.1599
# Epoch 961/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0289 - val_loss: 0.0380 - val_mean_absolute_error: 0.1538
# Epoch 962/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0274 - val_loss: 0.0383 - val_mean_absolute_error: 0.1504
# Epoch 963/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0291 - val_loss: 0.0371 - val_mean_absolute_error: 0.1490
# Epoch 964/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0287 - val_loss: 0.0385 - val_mean_absolute_error: 0.1508
# Epoch 965/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0288 - val_loss: 0.0383 - val_mean_absolute_error: 0.1522
# Epoch 966/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0247 - val_loss: 0.0405 - val_mean_absolute_error: 0.1575
# Epoch 967/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0234 - val_loss: 0.0383 - val_mean_absolute_error: 0.1515
# Epoch 968/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0256 - val_loss: 0.0388 - val_mean_absolute_error: 0.1519
# Epoch 969/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0248 - val_loss: 0.0396 - val_mean_absolute_error: 0.1541
# Epoch 970/1000
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0253 - val_loss: 0.0366 - val_mean_absolute_error: 0.1491
# Epoch 971/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0254 - val_loss: 0.0409 - val_mean_absolute_error: 0.1580
# Epoch 972/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0232 - val_loss: 0.0385 - val_mean_absolute_error: 0.1537
# Epoch 973/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_absolute_error: 0.0243 - val_loss: 0.0408 - val_mean_absolute_error: 0.1554
# Epoch 974/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0255 - val_loss: 0.0384 - val_mean_absolute_error: 0.1534
# Epoch 975/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0236 - val_loss: 0.0387 - val_mean_absolute_error: 0.1522
# Epoch 976/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0232 - val_loss: 0.0381 - val_mean_absolute_error: 0.1502
# Epoch 977/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0253 - val_loss: 0.0379 - val_mean_absolute_error: 0.1496
# Epoch 978/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0293 - val_loss: 0.0396 - val_mean_absolute_error: 0.1551
# Epoch 979/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0020 - mean_absolute_error: 0.0316 - val_loss: 0.0372 - val_mean_absolute_error: 0.1496
# Epoch 980/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0313 - val_loss: 0.0402 - val_mean_absolute_error: 0.1543
# Epoch 981/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0021 - mean_absolute_error: 0.0318 - val_loss: 0.0394 - val_mean_absolute_error: 0.1523
# Epoch 982/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0309 - val_loss: 0.0385 - val_mean_absolute_error: 0.1519
# Epoch 983/1000
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0329 - val_loss: 0.0356 - val_mean_absolute_error: 0.1451
# Epoch 984/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0022 - mean_absolute_error: 0.0330 - val_loss: 0.0373 - val_mean_absolute_error: 0.1504
# Epoch 985/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0400 - val_mean_absolute_error: 0.1564
# Epoch 986/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0320 - val_loss: 0.0383 - val_mean_absolute_error: 0.1520
# Epoch 987/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0266 - val_loss: 0.0391 - val_mean_absolute_error: 0.1555
# Epoch 988/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0259 - val_loss: 0.0380 - val_mean_absolute_error: 0.1514
# Epoch 989/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0240 - val_loss: 0.0409 - val_mean_absolute_error: 0.1589
# Epoch 990/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0217 - val_loss: 0.0394 - val_mean_absolute_error: 0.1550
# Epoch 991/1000
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0234 - val_loss: 0.0388 - val_mean_absolute_error: 0.1537
# Epoch 992/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0252 - val_loss: 0.0377 - val_mean_absolute_error: 0.1514
# Epoch 993/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0260 - val_loss: 0.0392 - val_mean_absolute_error: 0.1532
# Epoch 994/1000
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0262 - val_loss: 0.0373 - val_mean_absolute_error: 0.1489
# Epoch 995/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0021 - mean_absolute_error: 0.0327 - val_loss: 0.0381 - val_mean_absolute_error: 0.1528
# Epoch 996/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0023 - mean_absolute_error: 0.0340 - val_loss: 0.0373 - val_mean_absolute_error: 0.1493
# Epoch 997/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0019 - mean_absolute_error: 0.0313 - val_loss: 0.0409 - val_mean_absolute_error: 0.1575
# Epoch 998/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0265 - val_loss: 0.0383 - val_mean_absolute_error: 0.1502
# Epoch 999/1000
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0221 - val_loss: 0.0386 - val_mean_absolute_error: 0.1530
# Epoch 1000/1000
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0270 - val_loss: 0.0395 - val_mean_absolute_error: 0.1558
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 5, 32)             7424
#
#  lstm_23 (LSTM)              (None, 5, 32)             8320
#
#  lstm_24 (LSTM)              (None, 5, 32)             8320
#
#  lstm_25 (LSTM)              (None, 16)                3136
#
#  dense_19 (Dense)            (None, 32)                544
#
#  dense_20 (Dense)            (None, 8)                 264
#
#  dense_21 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 28,017
# Trainable params: 28,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #**Checking Validation Result**
#
# Model's performance with vaildation data

# %%
#Checking through trained model
y_pred = model.predict(X_val)
mse = MeanSquaredError()
val_er = mse(y_val.reshape(-1,1),y_pred)
print("Validation Error: ", val_er.numpy())

#Using Inverse Transformation for better Observation
plt.plot(pres_scaler.inverse_transform(y_val.reshape(-1,1)),'k', label='Original')
plt.plot(pres_scaler.inverse_transform(y_pred.reshape(-1,1)),'r', label='Prediction')
plt.ylabel("Pressure")
plt.xlabel("Datapoint")
plt.title("Validation Data Prediction")
plt.legend()
plt.show()
# Out:
# 5/5 [==============================] - 1s 4ms/step
# Validation Error:  0.039469782

# %% [markdown]
# ---

# %% [markdown]
# #**Checking Testing Result**
#
# From the above plot we can see some of the data points are innacurate, which can be caused by the highly fluctuating nature of hourly data points, so we are checking whether the model can predict the sensor reading correctly in the event of anamolies.
#
# Picking up date where failure occured:- 2015-05-21

# %%
#Date where another failure occured
st_test = df_sin.loc[df_sin['datetime']=="2015-05-21"].index.values[0]

#Filtering data to include approximately two-weeks window
start_period_test = st_test - 7*24
end_period_test = st_test + 7*24
X_test, y_test, test_scaler= create_feature(start_period_test, end_period_test)

#Shaping the sequence
X_test_seq = shape_sequence(X_test, 5, 0)
y_test_seq = shape_sequence(y_test, 1, 0)

#Predicting the testing data
y_pred_test = model.predict(X_test_seq)
test_er = mse(y_test_seq.reshape(-1,1), y_pred_test)
print("Testing Error = ", test_er.numpy())

#Selecting first 200 datapoints to allow for better plotting
#Returning the value using Inverse Transformation to allow better Observation
plt.plot(test_scaler.inverse_transform(y_pred_test[:200].reshape(-1,1)),'r', label="Prediction")
plt.plot(test_scaler.inverse_transform(y_test_seq[:200].reshape(-1,1)),'k', label="Original")
plt.ylabel("Pressure")
plt.xlabel("Datapoints")
plt.legend()
plt.show()
# Out:
# 11/11 [==============================] - 0s 4ms/step
# Testing Error =  0.049911488

# %% [markdown]
# ***We Observe that model can predict the sensor reading even in the event of machine failure, so we have to make sure the training data that we use to train should include past failure events as well***
